# %%
import pandas as pd
import numpy as np

# %%
data_one = pd.read_csv('data_one.csv')
data_two = pd.read_csv('data_two.csv')
train = pd.read_csv('data/train_and_test/train.csv')
test = pd.read_csv('data/train_and_test/test.csv')

# %%
data_one.head(12)
# Out:
#     user_id  create_count  create_day_mean  create_day_max  create_day_min  \
# 0        16           NaN              NaN             NaN             NaN
# 1        98           1.0            16.00            16.0            16.0
# 2       105           NaN              NaN             NaN             NaN
# 3       218           NaN              NaN             NaN             NaN
# 4       225           NaN              NaN             NaN             NaN
# 5       336           NaN              NaN             NaN             NaN
# 6       422           NaN              NaN             NaN             NaN
# 7       607           NaN              NaN             NaN             NaN
# 8       711           NaN              NaN             NaN             NaN
# 9       746           NaN              NaN             NaN             NaN
# 10      901           NaN              NaN             NaN             NaN
# ...

# %%
data_one['hot_mean'] = data_one.hot/data_one.create_count

# %%
data_two['hot_mean'] = data_two.hot/data_two.create_count
train['hot_mean'] = train.hot/train.create_count
test['hot_mean'] = test.hot/test.create_count

# %%
data_one.to_csv('data_one.csv', index=False)
data_two.to_csv('data_two.csv', index=False)
train.to_csv('data/train_and_test/train.csv', index=False)
test.to_csv('data/train_and_test/test.csv', index=False)

# %%
a = pd.read_csv('result4/final2.csv')
b = pd.read_csv('pa5avbxadb.csv')

# %%
b.rename(columns={'105':'id'},inplace=True)

# %%
pd.merge(a,b,on='id')
# Out:
#             id
# 0        29769
# 1       782006
# 2       748723
# 3       493401
# 4       784237
# 5       486186
# 6       693318
# 7       804715
# 8      1081151
# 9       831780
# 10      255295
# 11      473136
# 12     1093541
# 13      861000
# 14      963698
# 15      691108
# 16     1218562
# 17      693837
# 18      408015
# 19     1114680
# 20      326068
# 21      270482
# 22       36722
# 23     1019514
# 24      786821
# 25      307612
# 26      466084
# 27      327711
# 28      971789
# 29      129028
# ...        ...
# 22354   392526
# 22355   763971
# 22356  1119325
# 22357   636987
# 22358  1222846
# 22359   772966
# 22360   909550
# 22361   761705
# 22362   109213
# 22363  1012905
# 22364  1316020
# 22365   500773
# 22366   636606
# 22367   868632
# 22368  1270642
# 22369  1317833
# 22370  1117680
# 22371   588855
# 22372    41325
# 22373   358672
# 22374   707805
# 22375   493940
# 22376   494225
# 22377   692462
# 22378   514943
# 22379   391113
# ...
