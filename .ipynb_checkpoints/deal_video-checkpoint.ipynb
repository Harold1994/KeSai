# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
act = pd.read_csv('data/user_activity_log.csv')
cre = pd.read_csv('data/video_create_log.csv')

# %%
act.head()
# Out:
#    user_id  day  page  video_id  author_id  action_type
# 0  1062323   22     3   2877472     880271            0
# 1   639898   17     3    740662     210200            0
# 2  1260200    5     3   3332414     162866            0
# 3   817201   22     3   1129617     530246            0
# 4   817201   23     3   1129617     530246            0

# %%
cre.head()
# Out:
#    user_id  day
# 0   720497    1
# 1   720497    1
# 2   720497    1
# 3  1075211    6
# 4  1075211   12

# %%
vid = pd.DataFrame(act.video_id)
vid['hot'] = 1
vid.head()
# Out:
#    video_id  hot
# 0   2877472    1
# 1    740662    1
# 2   3332414    1
# 3   1129617    1
# 4   1129617    1

# %%
aut = pd.DataFrame(act.author_id)
aut['hot'] = 1
aut.head()
# Out:
#    author_id  hot
# 0     880271    1
# 1     210200    1
# 2     162866    1
# 3     530246    1
# 4     530246    1

# %%
v = vid.groupby('video_id').count()
a = aut.groupby('author_id').count()

# %%
v.reset_index(inplace=True)
a.reset_index(inplace=True)

# %%
v_norm = (v.hot - v.hot.min()) / (v.hot.max() - v.hot.min())

# %%
v.hot = v_norm *100

# %%
a_norm = (a.hot - a.hot.min()) / (a.hot.max() - a.hot.min())
a.hot = a_norm * 100

# %%
a.tail()
# Out:
#          author_id       hot
# 1322297    1367530  0.000000
# 1322298    1367531  0.010585
# 1322299    1367533  0.000000
# 1322300    1367535  0.010585
# 1322301    1367536  0.000000

# %%
a.rename(columns={'hot':'auth_hotness'}, inplace=True)
v.rename(columns={'hot':'vid_hotness'}, inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-56294764b783> in <module>()
# ----> 1 a.author_id()
#
# ~/Documents/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'author_id'

# %%
act = pd.merge(act,v,on='video_id',how='left')
act = pd.merge(act,a,on='author_id',how='left')

# %%
act.head()
# Out:
#    user_id  day  page  video_id  author_id  action_type  vid_hotness  \
# 0  1062323   22     3   2877472     880271            0     0.000000
# 1   639898   17     3    740662     210200            0     0.000000
# 2  1260200    5     3   3332414     162866            0     0.000000
# 3   817201   22     3   1129617     530246            0     0.045372
# 4   817201   23     3   1129617     530246            0     0.045372
#
#    auth_hotness
# 0      0.095265
# 1      0.000000
# 2      0.024698
# 3      0.356362
# 4      0.356362

# %%
act.to_csv('data/user_activity_log.csv', index=False)

# %%
act.auth_hotness.describe()
# Out:
# count    4.675000e+06
# mean     6.275666e+00
# std      1.289439e+01
# min      0.000000e+00
# 25%      4.030577e-01
# 50%      1.869354e+00
# 75%      6.087561e+00
# max      1.000000e+02
# Name: auth_hotness, dtype: float64

# %%
act.head()
# Out:
#    user_id  day  page  video_id  author_id  action_type  vid_hotness
# 0  1062323   22     3   2877472     880271            0     0.000000
# 1   639898   17     3    740662     210200            0     0.000000
# 2  1260200    5     3   3332414     162866            0     0.000000
# 3   817201   22     3   1129617     530246            0     0.078309
# 4   817201   23     3   1129617     530246            0     0.078309

# %%
a.reset_index(inplace=True)

# %%
a.to_csv('data/creater_hotness.csv', index=False)

# %%
a
# Out:
#          author_id  hot
# 0                1    1
# 1                2    1
# 2                3    1
# 3                4    9
# 4                5    1
# 5                6    2
# 6                7    1
# 7                8    1
# 8                9    1
# 9               10    1
# 10              11    1
# 11              12    3
# 12              13    1
# 13              14    1
# 14              15    1
# 15              17    1
# 16              18    2
# 17              19    1
# 18              20    2
# 19              21    1
# 20              22    2
# 21              23    1
# 22              24    2
# 23              25    1
# 24              26    4
# 25              27    1
# 26              28    2
# 27              29    2
# 28              31    1
# 29              32    1
# ...            ...  ...
# 1322272    1367505    1
# 1322273    1367506    2
# 1322274    1367507    1
# 1322275    1367508    1
# 1322276    1367509    3
# 1322277    1367510    1
# 1322278    1367511    1
# 1322279    1367512    2
# 1322280    1367513    1
# 1322281    1367514    1
# 1322282    1367515    5
# 1322283    1367516    1
# 1322284    1367517    1
# 1322285    1367518    2
# 1322286    1367519    2
# 1322287    1367520    1
# 1322288    1367521    1
# 1322289    1367522    1
# 1322290    1367523    1
# 1322291    1367524    4
# 1322292    1367525    1
# 1322293    1367526    2
# 1322294    1367527    1
# 1322295    1367528    2
# 1322296    1367529    1
# 1322297    1367530    1
# 1322298    1367531    4
# 1322299    1367533    1
# 1322300    1367535    4
# 1322301    1367536    1
#
# [1322302 rows x 2 columns]
